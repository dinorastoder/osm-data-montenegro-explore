# %% [markdown]
# # OpenStreetMap (OSM) data for Podgorica, Montenegro

# %%
# Loading of packages required for this Notebook

# %pip install quackosm folium matplotlib mapclassify ipywidgets --quiet
# Out:
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Uvod
#
# ## Opis glavnih termina i biblioteka korištenih u radu
#
# #### OpenStreetMap (OSM)
#
# > Besplatna, kolaborativna mapa svijeta koju kreira i održava globalna zajednica volontera. Omogućava svima da uređuju, koriste i dijele geografske podatke poput puteva, zgrada i znamenitosti, što je čini široko korišćenim resursom za navigaciju, istraživanje i kartografske projekte. Dostupna na [www.openstreetmap.org](www.openstreetmap.org)
#
# #### PBF (Protocolbuffer Binary Format)
# > Kompaktan binarni format koji se koristi za skladištenje podataka iz OpenStreetMap-a (OSM). Dizajniran je za efikasno čuvanje velikih količina geografskih informacija, kao što su čvorovi, putevi i relacije, u manjoj veličini fajla u poređenju sa običnim XML formatom. PBF fajlovi se brže čitaju i pišu, što ih čini pogodnim za obradu i prenos velikih OSM datasetova.
#
# #### GeoPandas - python biblioteka
# > Open-source Python biblioteka koja proširuje mogućnosti pandas biblioteke za rad sa geoprostornim podacima. Omogućava jednostavnu manipulaciju, analizu i vizualizaciju geografskih informacija, integracijom sa bibliotekama poput shapely za geometrijske operacije i matplotlib za crtanje. GeoPandas podržava uobičajene prostorne formate fajlova, kao što su shapefiles i GeoJSON.
#
# #### GeoDataFrame
# > Struktura podataka u GeoPandas-u koja proširuje pandas DataFrame za skladištenje geoprostornih podataka, sa kolonom za geometriju koja predstavlja geografske karakteristike i omogućava prostorne operacije.
#
# #### QuackOSM - python biblioteka
# > Python biblioteka koja omogućava jednostavan pristup podacima iz OpenStreetMap (OSM) kroz API pozive. Ova biblioteka pruža alate za preuzimanje, analizu i manipulaciju OSM podacima, olakšavajući korisnicima rad sa geografskim informacijama. QuackOSM podržava različite operacije, uključujući pretragu po oznakama i geografskoj lokaciji, što je čini korisnom za projekte vezane za prostornu analizu i vizualizaciju.
#
# #### DuckDB - Python biblioteka
# > Pruža brzu i efikasnu analizu podataka koristeći sistem za upravljanje relacionim bazama podataka. Inspirisana SQLite-om, DuckDB je optimizovana za rad sa velikim skupovima podataka i analitičkim operacijama. Omogućava korisnicima da izvode SQL upite direktno iz Python okruženja, podržava rad sa različitim formatima podataka, kao što su Parquet i CSV, i može se lako integrisati sa popularnim bibliotekama poput pandas.
#
# #### Parquet fajl format
# > Kolonarni format za skladištenje podataka, pogodan za velike prostorne datasetove. Omogućava efikasno čitanje, kompresiju i evoluciju šeme, a uz bibliotekepoput GeoPandas-a koristi se za analizu i obradu podataka u GIS aplikacijama.

# %% [markdown]
# ## Izvori Podataka
#
# - Spisak srednjih škola u Crnoj Gori  (gov.me) - https://www.gov.me/dokumenta/8f8e0bd7-e06f-4b05-a854-f75246fab129
# - Spisak osnovnih škola u Crnoj Gori  (gov.me) - https://www.gov.me/en/documents/c9c8b98d-4fc8-4737-b33e-6f78405764fb
# - Skolska statiskika - https://www.skolskastatistika.edu.me/

# %% [markdown]
# ## Upotreba QuackOSM za pronalažanje i download podataka sa OSM
#
# ### Biblioteka komunicira sa provajderima OSM podataka kao sto su geofabrik.de i preuzima PBF fajlove

# %% [markdown]
# Prvo je potrebno zadati gemetriju koja se pretražuje u OSM podacima. Postoji više načina za ovaj korak a najpopularnija su ova dva:
# 1. Ručno zadavanje koordinata geometrije
# 2. Dobijanje geometrije na osnovu nekog pojma ili naziva
#
# U našem slučaju izabrali smo pristup br.2, pretragu za Glavni grad Podgorica.

# %%
import quackosm as qosm

# Finding geometry of Podgorica
area_podgorica = qosm.geocode_to_geometry("Capital Podgorica, Montenegro")
area_podgorica # Display found geometry
# Out:
# <POLYGON ((18.989 42.476, 19.016 42.462, 19.024 42.452, 19.036 42.448, 19.03...>

# %% [markdown]
# Nakon što imamo željenu geometriju, možemo iskoristi QuackOSM biblioteku da pronađemo PBF ekstrakte koji pokrivaju ovu geometriju.
# U nekim slučajevima zadana geometrija nije pokrivena samo jednim PBF ekstraktom, mora se spustiti više fajlova. U našem slučaju geometrija za Glavni grad podgorica je pokrivena jednim fajlom (https://download.geofabrik.de/europe/montenegro.html)

# %%
# Find suitable PBF file(s) of OSM that covers Podgorica geometry 
# And filter out OSM features only for that area
# And load in GeoDataFrame

gdf = qosm.convert_geometry_to_geodataframe(area_podgorica, osm_extract_source=qosm.osm_extracts.OsmExtractSource.geofabrik)
gdf # Show sample from downloaded and extracted GeoDataFrame
#par = gdf.to_parquet
#gdf
# Out:
# 100%|█████████████████████████████████████| 30.3M/30.3M [00:00<00:00, 27.7GB/s]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Finished operation in 0:00:13
#                                                               tags  \
# feature_id
# node/3578892172  {'name': 'Rogamski vrh', 'name:sr': 'Рогамски ...
# node/3578892830  {'name': 'Suvovrh', 'name:sr': 'Сувоврх', 'nat...
# node/3582654902  {'name': 'Bavan', 'name:sr': 'Баван', 'natural...
# node/7265071000                                  {'noexit': 'yes'}
# node/7266948188                                  {'noexit': 'yes'}
# ...                                                            ...
# way/1312106588   {'crossing': 'uncontrolled', 'crossing:marking...
# way/1312106589       {'footway': 'sidewalk', 'highway': 'footway'}
# way/1312329851       {'footway': 'sidewalk', 'highway': 'footway'}
# way/1312329852       {'footway': 'sidewalk', 'highway': 'footway'}
# way/1312329853                                 {'highway': 'path'}
#
#                                                           geometry
# feature_id
# node/3578892172                          POINT (19.63239 42.67624)
# node/3578892830                          POINT (19.62759 42.66757)
# node/3582654902                          POINT (19.65441 42.67543)
# node/7265071000                          POINT (19.27619 42.43833)
# node/7266948188                          POINT (19.29011 42.44732)
# ...                                                            ...
# way/1312106588   LINESTRING (19.24633 42.44595, 19.2463 42.4458...
# way/1312106589   LINESTRING (19.24627 42.44584, 19.24616 42.445...
# way/1312329851   LINESTRING (19.25166 42.44464, 19.25137 42.44471)
# way/1312329852   LINESTRING (19.25137 42.44471, 19.24962 42.44518)
# way/1312329853    LINESTRING (19.2496 42.44576, 19.24866 42.44607)
#
# [67290 rows x 2 columns]

# %% [markdown]
# #### Vizuelna provjera ekstrakovanih podataka
#
# Upoređujemo geometrije za Podgoricu, granicama pokrivenim u PBF fajlu i na kraju ekstraktovanim OSM objektima za zadatu regiju

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import geopandas as gpd

fig = plt.figure(figsize=(10, 10))
ax = fig.subplots()

gdf.plot(ax=ax, markersize=1, zorder=1, alpha=0.4)
gdf.boundary.plot(ax=ax, markersize=0, zorder=1, alpha=0.8)
gpd.GeoSeries([area_podgorica], crs=4326).plot(
    ax=ax,
    color=(0, 0, 0, 0),
    zorder=2,
    hatch="///",
    edgecolor="orange",
    linewidth=1.5,
    
)

blue_patch = mpatches.Patch(color="C0", alpha=0.8, label="Extracted OSM features")
orange_patch = mpatches.Patch(
    facecolor=(0, 0, 0, 0), edgecolor="orange", hatch="///", linewidth=1.5, label="Podgorica Geometry filter"
)
ax.legend(handles=[blue_patch, orange_patch], loc="lower right")
plt.show()

# %% [markdown]
# ### Provjera dostupnosti podataka vezanih za institucije obrazovanja u Podgorici

# %%
import geopandas as gpd

filter_kindergarten ={"building": "kindergarten", "amenity": "kindergarten"}
filter_school ={"building": "school", "amenity": "school"}
filter_university ={"building": "university", "amenity": "university"}

filter_kindergarten ={"amenity": "kindergarten"}
filter_school ={"amenity": "school"}
filter_university ={"amenity": "university"}

filter_kindergarten_building ={"building": "kindergarten", "amenity": False}
filter_school_building ={"building": "school", "amenity": False}
filter_university_building ={"building": "university", "amenity": False}

grouped_filter = {
    "kindergarten": filter_kindergarten,
    "school": filter_school,
    "university": filter_university,
}


# Select only OSM features that represent kindergartens in Podgorica area
gdf = qosm.convert_geometry_to_geodataframe(area_podgorica, tags_filter=filter_kindergarten, verbosity_mode="transient", keep_all_tags=True, explode_tags=True)
# Select only OSM features that represent schools in Podgorica area
gdf1 = qosm.convert_geometry_to_geodataframe(area_podgorica, tags_filter=filter_school, verbosity_mode="transient", keep_all_tags=True, explode_tags=True)
# Select only OSM features that represent universities in Podgorica area
gdf2 = qosm.convert_geometry_to_geodataframe(area_podgorica, tags_filter=filter_university, verbosity_mode="transient", keep_all_tags=True, explode_tags=True)


# Select only OSM features that represent kindergartens in Podgorica area
gdf_building = qosm.convert_geometry_to_geodataframe(area_podgorica, tags_filter=filter_kindergarten_building, verbosity_mode="transient", keep_all_tags=True, explode_tags=True)
# Select only OSM features that represent schools in Podgorica area
gdf1_building = qosm.convert_geometry_to_geodataframe(area_podgorica, tags_filter=filter_school_building, verbosity_mode="transient", keep_all_tags=True, explode_tags=True)
# Select only OSM features that represent universities in Podgorica area
gdf2_building = qosm.convert_geometry_to_geodataframe(area_podgorica, tags_filter=filter_university_building, verbosity_mode="transient", keep_all_tags=True, explode_tags=True)

gdf_joined = gdf.sjoin(gdf_building, how="left")
gdf1_joined = gdf1.sjoin(gdf1_building, how="left")
gdf2_joined = gdf2.sjoin(gdf2_building, how="left")

'''
print(gdf_joined.size)

# Prepare 3 layers with different colors
m = gdf.explore(color="orangered", tiles="CartoDB positron")
m2 = gdf1.explore(color="blue", m=m)
m3 = gdf2.explore(color="pink", m=m)
m4 = gdf_joined.explore(color="black", m=m)


# Draw interactive map for data visualisation and exploration
# gpd.GeoSeries([area_podgorica], crs=4326).boundary.explore(m=m)

gdf_joined["geometry"] = gdf_joined["geometry"].centroid
#gdf_joined.set_geometry("centroid")
gdf_joined["geometry"].to_crs(4326)
gdf_joined.explore()
#gdf_joined[["name_left", "amenity", "building_left", "building_right", "feature_id_right", "centroid", "geometry"]]
#gdf_joined.plot()
gdf1_joined[["name_left", "amenity", "building_left", "building_right", "isced:level"]]
#gdf2_joined[["name_left", "amenity", "building_left", "building_right"]]

'''

gdf2_joined[["feature_id_right", "name_left", "amenity", "building_left", "building_right"]]
#gdf[["name", "amenity", "isced:level", "building", "landuse"]]
#gdf
#gdf.explore()
#gdf2.to_parquet(path="osm.university.20241104.parquet")
# Out:
#                 feature_id_right                     name_left     amenity  \
# feature_id_left
# node/308976329               NaN                          None  university
# node/4770166029              NaN         Univerzitet Mediteran  university
# node/4345473682              NaN     Fakultet Političkih Nauka  university
# way/28131830                 NaN  Ekonomski fakultet Podgorica  university
# way/28131839                 NaN               Pravni fakultet  university
# way/185576891       way/28092779         Univerzitet Crne Gore  university
# way/185576891       way/28538070         Univerzitet Crne Gore  university
# way/312760420                NaN      Univerzitet Donja Gorica  university
#
#                 building_left building_right
# feature_id_left
# node/308976329           None            NaN
# node/4770166029          None            NaN
# node/4345473682          None            NaN
# way/28131830              yes            NaN
# way/28131839              yes            NaN
# way/185576891            None     university
# way/185576891            None     university
# way/312760420      university            NaN

# %%
import pandas as pd


gdf["object_type"] = "kindergarten"
gdf1["object_type"] = "school"
gdf2["object_type"] = "university"

dataframesList = [gdf, gdf1, gdf2] 

gdf_total = gpd.GeoDataFrame(pd.concat(dataframesList, ignore_index=True), crs=dataframesList[0].crs)
gdf_total
# Out:
# 3638

# %%
grouped_filter = {
    "kindergarten": filter_kindergarten,
    "school": filter_school,
    "university": filter_university,
}


# Select only OSM features that represent kindergartens in Podgorica area
gdf_grouped = qosm.convert_geometry_to_geodataframe(area_podgorica, tags_filter=grouped_filter, verbosity_mode="transient", explode_tags=True)

gdf_grouped.index
# Out:
# Index(['node/312726237', 'node/313316672', 'node/313316900', 'node/313316939',
#        'node/313316979', 'node/12246235617', 'node/12246278965',
#        'node/12246289107', 'node/12246842213', 'way/1322470963',
#        ...
#        'way/203944177', 'way/203944179', 'way/936915698', 'way/1021434550',
#        'way/283891857', 'way/293467443', 'way/293583485', 'way/293583488',
#        'way/529562660', 'way/529562662'],
#       dtype='object', name='feature_id', length=107)

# %%
import duckdb
import geopandas

# Using DuckDB load bus routes
duckdb.load_extension("spatial")
bus_routes_unnested = duckdb.sql(
    """
    SELECT
        id,
        kind,
        tags as route_tags,
        ref_roles,
        ref_types,
        refs
    FROM ST_ReadOSM("files/geofabrik_europe_montenegro.osm.pbf")
    WHERE (tags['amenity'][1] in ('kindergarten'))
    """
)

bus_routes_unnested
# Out:
# ┌────────────┬──────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬───────────┬───────────────────────────────────┬─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │     id     │                     kind                     │                                                                                                                                                                                          route_tags                                                                                                                                                                                           │ ref_roles │             ref_types             │                                                                                                            refs                                                                                                             │
# │   int64    │ enum('node', 'way', 'relation', 'changeset') │                                                                                                                                                                                     map(varchar, varchar)                                                                                                                                                                                     │ varchar[] │ enum('node', 'way', 'relation')[] │                                                                                                           int64[]                                                                                                           │
# ├────────────┼──────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────┼───────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 2225598221 │ node                                         │ {amenity=kindergarten}                                                                                                                                                                                                                                                                                                                                                                        │ NULL      │ NULL                              │ NULL                                                                                                                                                                                                                        │
# │ 2299516964 │ node                                         │ {amenity=kindergarten}                                                                                                                                                                                                                                                                                                                                                                        │ NULL      │ NULL                              │ NULL                                                                                                                                                                                                                        │
# │ 2301775003 │ node                                         │ {amenity=kindergarten, name=Dječiji vrtić "Boško Buha", name:sr=Дјечији вртић "Бошко Буха"}                                                                                                                                                                                                                                                                                                   │ NULL      │ NULL                              │ NULL                                                                                                                                                                                                                        │
# │ 2430539386 │ node                                         │ {amenity=kindergarten, name=Vrtic "Pinokio", operator=Predškolska ustanova “Artić Pinokio”, operator:type=private}                                                                                                                                                                                                                                                                            │ NULL      │ NULL                              │ NULL                                                                                                                                                                                                                        │
# │ 2590698218 │ node                                         │ {amenity=kindergarten}                                                                                                                                                                                                                                                                                                                                                                        │ NULL      │ NULL                              │ NULL                                                                                                                                                                                                                        │
# │ 3274263376 │ node                                         │ {amenity=kindergarten}                                                                                                                                                                                                                                                                                                                                                                        │ NULL      │ NULL                              │ NULL                                                                                                                                                                                                                        │
# │ 4002176494 │ node                                         │ {amenity=kindergarten, name=Vtric "Svetionik"}                                                                                                                                                                                                                                                                                                                                                │ NULL      │ NULL                              │ NULL                                                                                                                                                                                                                        │
# │ 4002176495 │ node                                         │ {amenity=kindergarten, name=Vrtic "Mali Veliki Ljudi"}                                                                                                                                                                                                                                                                                                                                        │ NULL      │ NULL                              │ NULL                                                                                                                                                                                                                        │
# │ 4309982332 │ node                                         │ {amenity=kindergarten, name=Kosovka djevojka, name:sr=Косовка дјевојка}                                                                                                                                                                                                                                                                                                                       │ NULL      │ NULL                              │ NULL                                                                                                                                                                                                                        │
# │ 4857116122 │ node                                         │ {amenity=kindergarten, name=Vrtić}                                                                                                                                                                                                                                                                                                                                                            │ NULL      │ NULL                              │ NULL                                                                                                                                                                                                                        │
# │      ·     │  ·                                           │                 ·                                                                                                                                                                                                                                                                                                                                                                             │  ·        │  ·                                │  ·                                                                                                                                                                                                                          │
# │      ·     │  ·                                           │                 ·                                                                                                                                                                                                                                                                                                                                                                             │  ·        │  ·                                │  ·                                                                                                                                                                                                                          │
# │      ·     │  ·                                           │                 ·                                                                                                                                                                                                                                                                                                                                                                             │  ·        │  ·                                │  ·                                                                                                                                                                                                                          │
# │ 1323101121 │ way                                          │ {addr:street=Đoka Miraševića, amenity=kindergarten, area=yes, name=Vrtić "Simba", official_name=Vaspitna jedinica "Simba", operator=Javna Predškolska Ustanova "Ljubica Popović", operator:type=public/government, preschool=yes}                                                                                                                                                             │ NULL      │ NULL                              │ [12243388368, 12243388369, 12243388370, 12243388371, 12243388368]                                                                                                                                                           │
# │ 1323101762 │ way                                          │ {addr:housenumber=11, addr:street=Trg Nikole Kovačevića, amenity=kindergarten, area=yes, name=Vrtić "Sunce", name:sr=Дјечији вртић Сунце, official_name=Vaspitna jedinica “Sunce”, operator=Javna Predškolska Ustanova “Ljubica Popović”, operator:type=public, preschool=yes}                                                                                                                │ NULL      │ NULL                              │ [12243476902, 12243476903, 12243476904, 12243476905, 12243476902]                                                                                                                                                           │
# │ 1323102683 │ way                                          │ {amenity=kindergarten, area=yes, education=kindergarten, landuse=education, name=Vrtić "Pčelica", official_name=Vaspitna jedinica “Pčelica”, operator=Javna Predškolska Ustanova “Ljubica Popović”, operator:type=public, preschool=yes}                                                                                                                                                      │ NULL      │ NULL                              │ [12243477900, 12243488301, 12243488302, 1860789424, 2301671872, 12243488303, 12243477900]                                                                                                                                   │
# │ 1323398046 │ way                                          │ {amenity=kindergarten, landuse=education, name=Vrtic “Mali princ”, official_name=Vaspitna jedinica “Mali princ”, operator=Javna Predškolska Ustanova “Đina Vrbica”, operator:type=public, preschool=yes}                                                                                                                                                                                      │ NULL      │ NULL                              │ [1960234319, 1960234300, 12246101896, 12246101897, 12246147802, 12246101899, 12246101898, 1960234319]                                                                                                                       │
# │ 1323401187 │ way                                          │ {addr:city=Podgorica, addr:street=Bulevar Stanka Dragojevića, amenity=kindergarten, area=yes, landuse=education, name=Vrtić “Osmijeh”, official_name=Vaspitna jedinica “Osmijeh”, operator=Javna Predškolska Ustanova “Ljubica Popović”, operator:type=public}                                                                                                                                │ NULL      │ NULL                              │ [2073429526, 2073429529, 12246164541, 12246164542, 12246164543, 2073429533, 2073429526]                                                                                                                                     │
# │ 1323402930 │ way                                          │ {amenity=kindergarten, landuse=education, name=Vrtic “Bubamara”, official_name=Vaspitna jedinica “Bubamara”, operator=Javna Predškolska Ustanova “Đina Vrbica”, operator:type=public}                                                                                                                                                                                                         │ NULL      │ NULL                              │ [12246190653, 12246190654, 12246190655, 12246190656, 12246190653]                                                                                                                                                           │
# │ 1323410800 │ way                                          │ {amenity=kindergarten, area=yes, landuse=education, name=Vrtic "Stara varoš", official_name=Vaspitna jedinica "Stara varoš", operator=Javna Predškolska Ustanova “Đina Vrbica”, operator:type=public}                                                                                                                                                                                         │ NULL      │ NULL                              │ [12246237315, 12246237316, 12246237317, 12246237318, 2216450489, 2216450484, 12246237315]                                                                                                                                   │
# │ 1323424520 │ way                                          │ {addr:neighbourhood=Gornja Gorica, addr:street=Miloja Pavlovića, amenity=kindergarten, area=yes, landuse=education, name=Vrtić “Palčica”, official_name=Vaspitna jedinica “Palčica”, opening_hours=Mo-Fr 06:00-17:00, operator=Javna Predškolska Ustanova “Ljubica Popović”, operator:type=public, phone=+382 20 262 374, website=https://ljubicapopovic.me/v_jedinica/o_nama/7/Pal%C4%8Dica} │ NULL      │ NULL                              │ [9552206007, 9552205992, 12246364337, 12246364338, 9552206007]                                                                                                                                                              │
# │ 1323425422 │ way                                          │ {amenity=kindergarten, area=yes, landuse=education, mobile=+382 67 706 953, name=Vrtić “Bajka”, official_name=Vaspitna jedinica “Bajka”, opening_hours=Mo-Fr 06:00-17:00, operator=Javna Predškolska Ustanova “Ljubica Popović”, operator:type=public, phone=+382 20 260 040, website=https://ljubicapopovic.me/v_jedinica/o_nama/8/Bajka}                                                    │ NULL      │ NULL                              │ [12246409244, 12246409245, 12246409246, 12246409247, 12246409248, 12246409249, 12246409250, 12246409251, 12246409252, 12246409253, 12246409254, 12246409255, 12246409256, 12246409257, 3203247007, 3203247002, 12246409244] │
# │ 1323463396 │ way                                          │ {amenity=kindergarten, area=yes, landuse=education, name=Vrtić “Zvjezdice”, official_name=Vaspitna jedinica “Zvjezdice”, operator=Javna Predškolska Ustanova “Ljubica Popović”, operator:type=public, phone=+382 67 241 409, website=https://ljubicapopovic.me/v_jedinica/o_nama/6/Zvjezdice}                                                                                                 │ NULL      │ NULL                              │ [12246778172, 12246778173, 12246778174, 12246778175, 12246778176, 12246778172]                                                                                                                                              │
# ├────────────┴──────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴───────────┴───────────────────────────────────┴─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 63 rows (20 shown)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            6 columns │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ### Provjera OSM podataka za javni prevoz na teritoriji podgorice
#
# QuackOSM biblioteka ne podržava ekstrakciju linija gradskog prevoza, jer su zadate kao OSM objekat tipa relacija.
#
# Ovdje smo primijenili DuckDB biblioteku sa Spatial ekstenzijom koja jednostavno učitava PBF fajl i daje rezultate u DataFrame.

# %%
import duckdb
import geopandas

# Using DuckDB load bus routes
duckdb.load_extension("spatial")
bus_routes_unnested = duckdb.sql(
    """
    SELECT
        id,
        tags as route_tags,
        UNNEST(refs) as ref,
        UNNEST(ref_types) as ref_type,
        UNNEST(ref_roles) as ref_role
    FROM ST_ReadOSM("files/geofabrik_europe_montenegro.osm.pbf")
    WHERE kind = 'relation'
    AND tags['route'][1] = 'bus'
    """
).to_df()

# Combine the data in one object
bus_routes_unnested["feature_id"] = (
    bus_routes_unnested["ref_type"].astype(str) + "/" + bus_routes_unnested["ref"].astype(str)
)

# Load highway and public_transport features
highway_filter = {"highway": True, "public_transport": True}

features_gdf = qosm.convert_osm_extract_to_geodataframe(
    "geofabrik_europe_montenegro", tags_filter=highway_filter, keep_all_tags=True, geometry_filter=area_podgorica
)

features_gdf.explore()

bus_routes_with_geometries = bus_routes_unnested.merge(features_gdf, left_on="feature_id", right_index=True)
bus_routes_with_geometries = bus_routes_with_geometries.rename(
    columns={
        "id": "relation_route_id",
        "tags": "feature_tags",
    }
)

gdf = geopandas.GeoDataFrame(bus_routes_with_geometries, geometry="geometry", crs=4326)
gpd.GeoSeries([area_podgorica], crs=4326).boundary.explore(m=gdf.explore(color="orangered", tiles="CartoDB positron"))
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e98f56f9b07ce05ff19cb998396c6433 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e98f56f9b07ce05ff19cb998396c6433&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e98f56f9b07ce05ff19cb998396c6433 = L.map(
#                 &quot;map_e98f56f9b07ce05ff19cb998396c6433&quot;,
#                 {
#                     center: [42.520637550000004, 19.28322955],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e98f56f9b07ce05ff19cb998396c6433);
#
#
#
#
#
#             var tile_layer_a0582f8040085b6169d9bbb54bb83362 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a0582f8040085b6169d9bbb54bb83362.addTo(map_e98f56f9b07ce05ff19cb998396c6433);
#
#
#             map_e98f56f9b07ce05ff19cb998396c6433.fitBounds(
#                 [[42.3943713, 19.1865578], [42.6469038, 19.3799013]],
#                 {}
#             );
#
#
#         function geo_json_e965cf6c50fa4c82a11aa99b12038bcb_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;orangered&quot;, &quot;fillColor&quot;: &quot;orangered&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_e965cf6c50fa4c82a11aa99b12038bcb_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_e965cf6c50fa4c82a11aa99b12038bcb_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_e965cf6c50fa4c82a11aa99b12038bcb_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_e965cf6c50fa4c82a11aa99b12038bcb_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_e965cf6c50fa4c82a11aa99b12038bcb.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_e965cf6c50fa4c82a11aa99b12038bcb_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_e965cf6c50fa4c82a11aa99b12038bcb = L.geoJson(null, {
#                 onEachFeature: geo_json_e965cf6c50fa4c82a11aa99b12038bcb_onEachFeature,
#
#                 style: geo_json_e965cf6c50fa4c82a11aa99b12038bcb_styler,
#                 pointToLayer: geo_json_e965cf6c50fa4c82a11aa99b12038bcb_pointToLayer,
#         });
#
#         function geo_json_e965cf6c50fa4c82a11aa99b12038bcb_add (data) {
#             geo_json_e965cf6c50fa4c82a11aa99b12038bcb
#                 .addData(data);
#         }
#             geo_json_e965cf6c50fa4c82a11aa99b12038bcb_add({&quot;bbox&quot;: [19.1865578, 42.3943713, 19.3799013, 42.6469038], &quot;features&q

# %% [markdown]
# ## Analiza pokrivenosti obrazovnih institucija gradskim prevozom
#
# TODO: Različiti metodi analize
#
# ## Vizuelizicija podataka i priprema podataka za dalju upotrebu
#
# TODO: Istražiti različite metode vizualizacije
# TODO: Istražiti metode exporta, i omugužavanja pristupa podacima za druge upotrebe.

# %%
# %pip install streamlit --quiet
import streamlit as st
#import leafmap.foliumap as leafmap
import geopandas as gpd
import json

m = leafmap.Map(tiles="Stadia.AlidadeSmoothDark")

m.zoom_to_bounds((18.9894022, 42.3356869, 19.6647575, 42.7089575))

url = "webapp/data/osm.kindergarten.20241104.parquet"
gdf_kindergarten = gpd.read_parquet(url)
gdf_kindergarten = gdf_kindergarten.to_crs("EPSG:4326")
gdf_kindergarten = gdf_kindergarten[gdf_kindergarten["amenity"] == "kindergarten"]
gdf_kindergarten = gdf_kindergarten[["name", "geometry"]]
gdf_kindergarten["centroid"] = gdf_kindergarten.geometry.centroid
#gdf_kindergarten["geometry"] = gdf_kindergarten.centroid
gdf_kindergarten.explore(color="red", radius=250)
# Out:
# Note: you may need to restart the kernel to use updated packages.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aac2ac0784c35d040d453d66af746246 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aac2ac0784c35d040d453d66af746246&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aac2ac0784c35d040d453d66af746246 = L.map(
#                 &quot;map_aac2ac0784c35d040d453d66af746246&quot;,
#                 {
#                     center: [42.412030793269714, 19.24440417333252],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_aac2ac0784c35d040d453d66af746246);
#
#
#
#
#
#             var tile_layer_711160b393c0e7ab822eaaa344b2e117 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_711160b393c0e7ab822eaaa344b2e117.addTo(map_aac2ac0784c35d040d453d66af746246);
#
#
#             map_aac2ac0784c35d040d453d66af746246.fitBounds(
#                 [[42.3676719, 19.1885132], [42.45638968653943, 19.300295146665043]],
#                 {}
#             );
#
#
#         function geo_json_69e677b721c5462791182571869d9fe9_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_69e677b721c5462791182571869d9fe9_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_69e677b721c5462791182571869d9fe9_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_69e677b721c5462791182571869d9fe9_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_69e677b721c5462791182571869d9fe9_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_69e677b721c5462791182571869d9fe9.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_69e677b721c5462791182571869d9fe9_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_69e677b721c5462791182571869d9fe9 = L.geoJson(null, {
#                 onEachFeature: geo_json_69e677b721c5462791182571869d9fe9_onEachFeature,
#
#                 style: geo_json_69e677b721c5462791182571869d9fe9_styler,
#                 pointToLayer: geo_json_69e677b721c5462791182571869d9fe9_pointToLayer,
#                 radius: 250,
#         });
#
#         function geo_json_69e677b721c5462791182571869d9fe9_add (data) {
#             geo_json_69e677b721c5462791182571869d9fe9
#                 .addData(data);
#         }
#             geo_json_69e677b721c5462791182571869d9fe9_add({&quot;bbox&quot;: [19.1885132, 42.3676719, 19.300295146665043, 42.45638968653943], &quot;features&quot;: [{&quot;bbox&quot;: [19.2799359, 42.4317772, 19.2799359, 42.4317772], &quot;geometry&quot;: {&quot;coordinates&quot;: [19.2799359, 42.4317772], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;__folium_color&quot;: &quot;red&quot;, &quot;feature_id&quot;: &quot;node/2430539386&quot;, &quot;name&quot;: &quot;Vrtic \&quot;Pinokio\&quot;&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [19.2714897, 42.4379163, 19.2714897, 42.4379163], &quot;geometry&quot;: {&quot;coordinates&quot;: [19.2714
